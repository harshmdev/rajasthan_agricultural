# %%
#First we import all necessary libraries
import pandas as pd
import numpy as np

# %%
# Then we import all the datasets (This dataset is imported from kaggle named as "Agricultural dataset for rajasthan" owner-suraj)
price=pd.read_csv("/content/crop_price_data.csv")
production=pd.read_csv("/content/crop_production_data.csv")
sad=pd.read_csv("/content/soil_analysis_data.csv")
water_usage=pd.read_csv("/content/water_usage_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # Then we import all the datasets (This dataset is imported from kaggle named as "Agricultural dataset for rajasthan" owner-suraj)
# ----> 2 price=pd.read_csv("/content/crop_price_data.csv")
#       3 production=pd.read_csv("/content/crop_production_data.csv")
#       4 sad=pd.read_csv("/content/soil_analysis_data.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
price.head()
# Out:
#          District         Crop            Market        Date  \
# 0           Alwar       Barley  Alwar APMC Mandi  2018-09-05
# 1  Sri Ganganagar  Pomegranate    Padampur Mandi  2018-11-20
# 2            Kota        Maize     Ramganj Mandi  2018-04-06
# 3          Nagaur    Fenugreek     Didwana Mandi  2018-09-26
# 4          Nagaur         Gram     Didwana Mandi  2018-10-06
#
#    Price (INR/quintal)
# 0          2490.092421
# 1          2348.904922
# 2          2448.287513
# 3          2714.419518
# 4          2883.356997

# %%
production.head()
# Out:
#       District       Crop  Season  Area (hectares)  Yield (quintals)  \
# 0      Jodhpur      Wheat  Kharif     16490.142459         30.691986
# 1         Kota       Gram    Rabi     16943.065614         45.818232
# 2       Jaipur      Wheat    Rabi     14297.539876         29.752629
# 3  Hanumangarh  Coriander    Rabi     19737.638447         42.026511
# 4  Hanumangarh     Citrus    Rabi     13591.576842         38.195933
#
#    Production (metric tons)
# 0               5061.152230
# 1               7763.013072
# 2               4253.893981
# 3               8295.040749
# 4               5191.429648

# %%
sad.head()
# Out:
#    District            Soil Type  pH Level  Organic Matter (%)  \
# 0    Jaipur  Chalky (Calcareous)  6.546096            1.569807
# 1  Bhilwara          Nitrogenous  6.832259            2.243018
# 2   Jodhpur                Sandy  7.453182            2.662898
# 3    Jaipur                 Clay  8.019189            1.240327
# 4    Jaipur                Sandy  8.100131            1.768419
#
#    Nitrogen Content (kg/ha)  Phosphorus Content (kg/ha)  \
# 0                 27.931972                   29.438438
# 1                 22.263480                   25.413455
# 2                 23.564182                   13.014409
# 3                 15.839222                   17.744206
# 4                 27.942867                   25.769504
#
#    Potassium Content (kg/ha)
# 0                  42.782766
# 1                  37.644377
# 2                  37.082003
# 3                  42.758704
# 4                  30.651292

# %%
water_usage.head()
# Out:
#    District    Crop     Irrigation Method  Water Consumption (liters/hectare)  \
# 0   Udaipur  Garlic             Tube Well                        11609.330886
# 1  Bhilwara    Gram       Drip Irrigation                        12648.406038
# 2   Udaipur   Guava      Canal Irrigation                        10063.162448
# 3   Jodhpur  Barley  Sprinkler Irrigation                        10110.539993
# 4     Alwar    Gram      Canal Irrigation                         9320.451018
#
#    Water Availability (liters/hectare)
# 0                         11335.919980
# 1                         12091.900254
# 2                          9810.943169
# 3                         10754.217313
# 4                          8695.537819
